# %% [markdown]
# <a href="https://colab.research.google.com/github/afrina23/Single-Image-Crowd-Counting-with-MCNN/blob/master/FineTuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mounting to the google drive for data.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# necessary imports and functions and the model itself

# %%
import os
import cv2
import time

import torch
import torch.nn as nn
from torch.autograd import Variable
import random
import pandas as pd

import numpy as np
import sys

#from src.crowd_count import CrowdCounter
#from src import network
#from src.data_loader import ImageDataLoader
#from src.timer import Timer
#from src import utils
#from src.evaluate_model import evaluate_model

try:
    from termcolor import cprint
except ImportError:
    cprint = None

try:
    from pycrayon import CrayonClient
except ImportError:
    CrayonClient = None


def log_print(text, color=None, on_color=None, attrs=None):
    if cprint is not None:
        cprint(text, color=color, on_color=on_color, attrs=attrs)
    else:
        print(text)


def save_results(input_img, gt_data, density_map, output_dir, fname='results.png'):
    input_img = input_img[0][0]
    gt_data = 255 * gt_data / np.max(gt_data)
    density_map = 255 * density_map / np.max(density_map)
    gt_data = gt_data[0][0]
    density_map = density_map[0][0]
    if density_map.shape[1] != input_img.shape[1]:
        density_map = cv2.resize(density_map, (input_img.shape[1], input_img.shape[0]))
        gt_data = cv2.resize(gt_data, (input_img.shape[1], input_img.shape[0]))
    result_img = np.hstack((input_img, gt_data, density_map))
    cv2.imwrite(os.path.join(output_dir, fname), result_img)


def save_density_map(density_map, output_dir, fname='results.png'):
    density_map = 255 * density_map / np.max(density_map)
    density_map = density_map[0][0]
    cv2.imwrite(os.path.join(output_dir, fname), density_map)


def display_results(input_img, gt_data, density_map):
    input_img = input_img[0][0]
    gt_data = 255 * gt_data / np.max(gt_data)
    density_map = 255 * density_map / np.max(density_map)
    gt_data = gt_data[0][0]
    density_map = density_map[0][0]
    if density_map.shape[1] != input_img.shape[1]:
        input_img = cv2.resize(input_img, (density_map.shape[1], density_map.shape[0]))
    result_img = np.hstack((input_img, gt_data, density_map))
    result_img = result_img.astype(np.uint8, copy=False)
    cv2.imshow('Result', result_img)
    cv2.waitKey(0)




class Timer(object):
    def __init__(self):
        self.tot_time = 0.
        self.calls = 0
        self.start_time = 0.
        self.diff = 0.
        self.average_time = 0.

    def tic(self):
        # using time.time instead of time.clock because time time.clock
        # does not normalize for multithreading
        self.start_time = time.time()

    def toc(self, average=True):
        self.diff = time.time() - self.start_time
        self.tot_time += self.diff
        self.calls += 1
        self.average_time = self.tot_time / self.calls
        if average:
            return self.average_time
        else:
            return self.diff


class ImageDataLoader():
    def __init__(self, data_path, gt_path, shuffle=False, gt_downsample=False, pre_load=False):
        # pre_load: if true, all training and validation images are loaded into CPU RAM for faster processing.
        #          This avoids frequent file reads. Use this only for small datasets.
        self.data_path = data_path
        self.gt_path = gt_path
        self.gt_downsample = gt_downsample
        self.pre_load = pre_load
        #print(os.listdir(data_path))
        
        self.data_files = [filename for filename in os.listdir(data_path) \
                           if os.path.isfile(os.path.join(data_path, filename))]
        self.data_files.sort()
        #print("size of data file ", self.data_files)
        self.shuffle = shuffle
        if shuffle:
            random.seed(2468)
        self.num_samples = len(self.data_files)
        self.blob_list = {}
        self.id_list = range(0, self.num_samples)
        if self.pre_load:
            print
            'Pre-loading the data. This may take a while...'
            idx = 0
            for fname in self.data_files:

                img = cv2.imread(os.path.join(self.data_path, fname), 0)
                img = img.astype(np.float32, copy=False)
                ht = img.shape[0]
                wd = img.shape[1]
                ht_1 = int(ht / 4) * 4
                wd_1 = int(wd / 4) * 4
                img = cv2.resize(img, (wd_1, ht_1))
                img = img.reshape((1, 1, img.shape[0], img.shape[1]))
                den = pd.read_csv(os.path.join(self.gt_path, os.path.splitext(fname)[0] + '.csv'), sep=',',
                                  header=None).as_matrix()
                den = den.astype(np.float32, copy=False)
                #print(wd_1,ht_1)
                if self.gt_downsample:
                    wd_1 = int(wd_1 / 4)
                    ht_1 = int(ht_1 / 4)
                    #print(wd_1,ht_1)
                    den = cv2.resize(den, (wd_1, ht_1))
                    den = den * ((wd * ht) / (wd_1 * ht_1))
                else:
                    den = cv2.resize(den, (wd_1, ht_1))
                    den = den * ((wd * ht) / (wd_1 * ht_1))

                den = den.reshape((1, 1, den.shape[0], den.shape[1]))
                blob = {}
                blob['data'] = img
                blob['gt_density'] = den
                blob['fname'] = fname
                self.blob_list[idx] = blob
                idx = idx + 1
                if idx % 100 == 0:
                    print
                    'Loaded ', idx, '/', self.num_samples, 'files'

            print
            'Completed Loading ', idx, 'files'

    def __iter__(self):
        if self.shuffle:
            if self.pre_load:
                random.shuffle(self.id_list)
            else:
                random.shuffle(self.data_files)
        files = self.data_files
        id_list = self.id_list

        for idx in id_list:
            if self.pre_load:
                blob = self.blob_list[idx]
                blob['idx'] = idx
            else:
                fname = files[idx]
                img = cv2.imread(os.path.join(self.data_path, fname), 0)
                img = img.astype(np.float32, copy=False)
                ht = img.shape[0]
                wd = img.shape[1]
                ht_1 = (ht / 4) * 4
                wd_1 = (wd / 4) * 4
                img = cv2.resize(img, (wd_1, ht_1))
                img = img.reshape((1, 1, img.shape[0], img.shape[1]))
                den = pd.read_csv(os.path.join(self.gt_path, os.path.splitext(fname)[0] + '.csv'), sep=',',
                                  header=None).as_matrix()
                den = den.astype(np.float32, copy=False)
                if self.gt_downsample:
                    wd_1 = wd_1 / 4
                    ht_1 = ht_1 / 4
                    den = cv2.resize(den, (wd_1, ht_1))
                    den = den * ((wd * ht) / (wd_1 * ht_1))
                else:
                    den = cv2.resize(den, (wd_1, ht_1))
                    den = den * ((wd * ht) / (wd_1 * ht_1))

                den = den.reshape((1, 1, den.shape[0], den.shape[1]))
                blob = {}
                blob['data'] = img
                blob['gt_density'] = den
                blob['fname'] = fname

            yield blob

    def get_num_samples(self):
        return self.num_samples


class Conv2d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1, relu=True, same_padding=False, bn=False):
        super(Conv2d, self).__init__()
        padding = int((kernel_size - 1) / 2) if same_padding else 0
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding=padding)
        self.bn = nn.BatchNorm2d(out_channels, eps=0.001, momentum=0, affine=True) if bn else None
        self.relu = nn.ReLU(inplace=True) if relu else None

    def forward(self, x):
        x = self.conv(x)
        if self.bn is not None:
            x = self.bn(x)
        if self.relu is not None:
            x = self.relu(x)
        return x


class FC(nn.Module):
    def __init__(self, in_features, out_features, relu=True):
        super(FC, self).__init__()
        self.fc = nn.Linear(in_features, out_features)
        self.relu = nn.ReLU(inplace=True) if relu else None

    def forward(self, x):
        x = self.fc(x)
        if self.relu is not None:
            x = self.relu(x)
        return x


def save_net(fname, net):
    import h5py
    h5f = h5py.File(fname, mode='w')
    for k, v in net.state_dict().items():
        h5f.create_dataset(k, data=v.cpu().numpy())


def load_net(fname, net):
    import h5py
    h5f = h5py.File(fname, mode='r')
    for k, v in net.state_dict().items():
        param = torch.from_numpy(np.asarray(h5f[k]))
        v.copy_(param)


def np_to_variable(x, is_cuda=True, is_training=False, dtype=torch.FloatTensor):
    if is_training:
        v = Variable(torch.from_numpy(x).type(dtype))
    else:
        v = Variable(torch.from_numpy(x).type(dtype), requires_grad = False, volatile = True)
    if is_cuda:
        v = v.cuda()
    return v


def set_trainable(model, requires_grad):
    for param in model.parameters():
        param.requires_grad = requires_grad


def weights_normal_init(model, dev=0.01):
    if isinstance(model, list):
        for m in model:
            weights_normal_init(m, dev)
    else:
        for m in model.modules():
            if isinstance(m, nn.Conv2d):
                #print torch.sum(m.weight)
                m.weight.data.normal_(0.0, dev)
                if m.bias is not None:
                    m.bias.data.fill_(0.0)
            elif isinstance(m, nn.Linear):
                m.weight.data.normal_(0.0, dev)


class MCNN(nn.Module):
    '''
    Multi-column CNN
        -Implementation of Single Image Crowd Counting via Multi-column CNN (Zhang et al.)
    '''

    def __init__(self, bn=False):
        super(MCNN, self).__init__()

        self.branch1 = nn.Sequential(Conv2d(1, 16, 9, same_padding=True, bn=bn),
                                     nn.MaxPool2d(2),
                                     Conv2d(16, 32, 7, same_padding=True, bn=bn),
                                     nn.MaxPool2d(2),
                                     Conv2d(32, 16, 7, same_padding=True, bn=bn),
                                     Conv2d(16, 8, 7, same_padding=True, bn=bn))

        self.branch2 = nn.Sequential(Conv2d(1, 20, 7, same_padding=True, bn=bn),
                                     nn.MaxPool2d(2),
                                     Conv2d(20, 40, 5, same_padding=True, bn=bn),
                                     nn.MaxPool2d(2),
                                     Conv2d(40, 20, 5, same_padding=True, bn=bn),
                                     Conv2d(20, 10, 5, same_padding=True, bn=bn))

        self.branch3 = nn.Sequential(Conv2d(1, 24, 5, same_padding=True, bn=bn),
                                     nn.MaxPool2d(2),
                                     Conv2d(24, 48, 3, same_padding=True, bn=bn),
                                     nn.MaxPool2d(2),
                                     Conv2d(48, 24, 3, same_padding=True, bn=bn),
                                     Conv2d(24, 12, 3, same_padding=True, bn=bn))

        self.fuse = nn.Sequential(Conv2d(30, 1, 1, same_padding=True, bn=bn))

    def forward(self, im_data):
        x1 = self.branch1(im_data)
        x2 = self.branch2(im_data)
        x3 = self.branch3(im_data)
        x = torch.cat((x1, x2, x3), 1)
        x = self.fuse(x)

        return x






class CrowdCounter(nn.Module):
    def __init__(self):
        super(CrowdCounter, self).__init__()
        self.DME = MCNN()
        self.loss_fn = nn.MSELoss()

    @property
    def loss(self):
        return self.loss_mse

    def forward(self, im_data, gt_data=None):
        im_data = np_to_variable(im_data, is_cuda=True, is_training=self.training)
        density_map = self.DME(im_data)

        if self.training:
            gt_data = np_to_variable(gt_data, is_cuda=True, is_training=self.training)
            self.loss_mse = self.build_loss(density_map, gt_data)

        return density_map

    def build_loss(self, density_map, gt_data):
        loss = self.loss_fn(density_map, gt_data)
        return loss



def evaluate_model(trained_model, data_loader):
    net = CrowdCounter()
    load_net(trained_model, net)
    net.cuda()
    net.eval()
    mae = 0.0
    mse = 0.0
    for blob in data_loader:
        im_data = blob['data']
        gt_data = blob['gt_density']
        density_map = net(im_data, gt_data)
        density_map = density_map.data.cpu().numpy()
        gt_count = np.sum(gt_data)
        et_count = np.sum(density_map)
        mae += abs(gt_count-et_count)
        mse += ((gt_count-et_count)*(gt_count-et_count))
    #print(mae)
    #print(data_loader.get_num_samples())    
    mae = mae/data_loader.get_num_samples()
    mse = np.sqrt(mse/data_loader.get_num_samples())
    return mae,mse

# %% [markdown]
# Fine tuning with dataset B or ucf_cc_50

# %%
method = 'mcnn_pretrain_A_to_B'
dataset_name = 'ucfc'
output_dir = '/content/gdrive/My Drive/project_folder/crowdcount-mcnn/saved_pretrained_last_two_layer_models_A_ucfc/'

train_path = '/content/gdrive/My Drive/project_folder/crowdcount-mcnn/data/formatted_trainval/ucfc_patches_9/train'
train_gt_path = '/content/gdrive/My Drive/project_folder/crowdcount-mcnn/data/formatted_trainval/ucfc_patches_9/train_den'
val_path = '/content/gdrive/My Drive/project_folder/crowdcount-mcnn/data/formatted_trainval/ucfc_patches_9/val'
val_gt_path = '/content/gdrive/My Drive/project_folder/crowdcount-mcnn/data/formatted_trainval/ucfc_patches_9/val_den'

#train_path = '/content/gdrive/My Drive/project_folder/crowdcount-mcnn/data/formatted_trainval/shanghaitech_part_B_patches_9/train'
#train_gt_path = '/content/gdrive/My Drive/project_folder/crowdcount-mcnn/data/formatted_trainval/shanghaitech_part_B_patches_9/train_den'
#val_path = '/content/gdrive/My Drive/project_folder/crowdcount-mcnn/data/formatted_trainval/shanghaitech_part_B_patches_9/val'
#val_gt_path = '/content/gdrive/My Drive/project_folder/crowdcount-mcnn/data/formatted_trainval/shanghaitech_part_B_patches_9/val_den'


model_path = '/content/gdrive/My Drive/project_folder/crowdcount-mcnn/saved_models/mcnn_shtechA_1942.h5'

# training configuration
start_step = 0
end_step = 1000
lr = 0.00001
momentum = 0.9
disp_interval = 500
log_interval = 250

# Tensorboard  config
use_tensorboard = False
save_exp_name = method + '_' + dataset_name + '_' + 'v1'
remove_all_log = False  # remove all historical experiments in TensorBoard
exp_name = None  # the previous experiment name in TensorBoard

# ------------
rand_seed = 64678
if rand_seed is not None:
    np.random.seed(rand_seed)
    torch.manual_seed(rand_seed)
    torch.cuda.manual_seed(rand_seed)

# load net
net = CrowdCounter()
trained_model = os.path.join(model_path)
load_net(trained_model, net)

for param in net.parameters():
    param.requires_grad = False

net.DME.branch1[5] = Conv2d(16, 8, 7, same_padding=True, bn=False)

net.DME.branch2[5] = Conv2d(20, 10, 5, same_padding=True, bn=False)

net.DME.branch3[5] = Conv2d(24, 12, 3, same_padding=True, bn=False)

net.DME.fuse = nn.Sequential(Conv2d(30, 1, 1, same_padding=True, bn=False))    
net.cuda()
net.train()


print(net)

total_params = sum(p.numel() for p in net.parameters())
print(f'{total_params:,} total parameters.')
total_trainable_params = sum(
    p.numel() for p in net.parameters() if p.requires_grad)
print(f'{total_trainable_params:,} training parameters.')


params = list(net.parameters())
optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, net.parameters()), lr=lr)

if not os.path.exists(output_dir):
    os.mkdir(output_dir)

# tensorboad
use_tensorboard = use_tensorboard and CrayonClient is not None
if use_tensorboard:
    cc = CrayonClient(hostname='127.0.0.1')
    if remove_all_log:
        cc.remove_all_experiments()
    if exp_name is None:
        exp_name = save_exp_name
        exp = cc.create_experiment(exp_name)
    else:
        exp = cc.open_experiment(exp_name)

# training
train_loss = 0
step_cnt = 0
re_cnt = False
t = Timer()
t.tic()

data_loader = ImageDataLoader(train_path, train_gt_path, shuffle=False, gt_downsample=True, pre_load=True)
data_loader_val = ImageDataLoader(val_path, val_gt_path, shuffle=False, gt_downsample=True, pre_load=True)
best_mae = 10000000000000000
#print(data_loader)
for epoch in range(start_step, end_step + 1):
    step = -1
    train_loss = 0
    print(data_loader.get_num_samples)
    for blob in data_loader:
        step = step + 1
        im_data = blob['data']
        #print(im_data)
        gt_data = blob['gt_density']
        density_map = net(im_data, gt_data)
        loss = net.loss
        #train_loss += loss.data[0]
        #print(type(loss))
        train_loss += loss.item()
        step_cnt += 1
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if step % disp_interval == 0:
            duration = t.toc(average=False)
            fps = step_cnt / duration
            gt_count = np.sum(gt_data)
            density_map = density_map.data.cpu().numpy()
            et_count = np.sum(density_map)
            save_results(im_data, gt_data, density_map, output_dir)
            log_text = 'epoch: %4d, step %4d, Time: %.4fs, gt_cnt: %4.1f, et_cnt: %4.1f' % (epoch,
                                                                                            step, 1. / fps, gt_count,
                                                                                            et_count)
            log_print(log_text, color='green', attrs=['bold'])
            re_cnt = True

        if re_cnt:
            t.tic()
            re_cnt = False

    if (epoch % 2 == 0):
        save_name = os.path.join(output_dir, '{}_{}_{}.h5'.format(method, dataset_name, epoch))
        save_net(save_name, net)
        # calculate error on the validation dataset
        mae, mse = evaluate_model(save_name, data_loader_val)
        if mae < best_mae:
            best_mae = mae
            best_mse = mse
            best_model = '{}_{}_{}.h5'.format(method, dataset_name, epoch)
        log_text = 'EPOCH: %d, MAE: %.1f, MSE: %0.1f' % (epoch, mae, mse)
        log_print(log_text, color='green', attrs=['bold'])
        log_text = 'BEST MAE: %0.1f, BEST MSE: %0.1f, BEST MODEL: %s' % (best_mae, best_mse, best_model)
        log_print(log_text, color='green', attrs=['bold'])
        if use_tensorboard:
            exp.add_scalar_value('MAE', mae, step=epoch)
            exp.add_scalar_value('MSE', mse, step=epoch)
            exp.add_scalar_value('train_loss', train_loss / data_loader.get_num_samples(), step=epoch)
# Out:
# CrowdCounter(
#   (DME): MCNN(
#     (branch1): Sequential(
#       (0): Conv2d(
#         (conv): Conv2d(1, 16, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#         (relu): ReLU(inplace=True)
#       )
#       (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): Conv2d(
#         (conv): Conv2d(16, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#         (relu): ReLU(inplace=True)
#       )
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): Conv2d(
#         (conv): Conv2d(32, 16, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#         (relu): ReLU(inplace=True)
#       )
#       (5): Conv2d(
#         (conv): Conv2d(16, 8, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (branch2): Sequential(
#       (0): Conv2d(
#         (conv): Conv2d(1, 20, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#         (relu): ReLU(inplace=True)
#       )
#       (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): Conv2d(
#         (conv): Conv2d(20, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (relu): ReLU(inplace=True)
#       )
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): Conv2d(
#         (conv): Conv2d(40, 20, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (relu): ReLU(inplace=True)
#       )
#       (5): Conv2d(
#         (conv): Conv2d(20, 10, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): Conv2d(
#         (conv): Conv2d(1, 24, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (relu): ReLU(inplace=True)
#       )
#       (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): Conv2d(
#         (conv): Conv2d(24, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): Conv2d(
#         (conv): Conv2d(48, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (5): Conv2d(
#         (conv): Conv2d(24, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (fuse): Sequential(
#       (0): Conv2d(
#         (conv): Conv2d(30, 1, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (loss_fn): MSELoss()
# )
# 127,953 total parameters.
# 13,925 training parameters.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:132: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:    0, step    0, Time: 155.3709s, gt_cnt: 115.3, et_cnt:  0.1
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:255: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# EPOCH: 0, MAE: 33.4, MSE: 40.6
# BEST MAE: 33.4, BEST MSE: 40.6, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_0.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:    1, step    0, Time: 0.0051s, gt_cnt: 115.3, et_cnt:  0.7
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:    2, step    0, Time: 0.0025s, gt_cnt: 115.3, et_cnt: 12.9
# EPOCH: 2, MAE: 13.2, MSE: 16.2
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:    3, step    0, Time: 0.0017s, gt_cnt: 115.3, et_cnt: 62.7
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:    4, step    0, Time: 0.0012s, gt_cnt: 115.3, et_cnt: 92.8
# EPOCH: 4, MAE: 14.5, MSE: 19.7
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:    5, step    0, Time: 0.0010s, gt_cnt: 115.3, et_cnt: 102.6
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:    6, step    0, Time: 0.0008s, gt_cnt: 115.3, et_cnt: 106.8
# EPOCH: 6, MAE: 17.6, MSE: 22.9
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:    7, step    0, Time: 0.0007s, gt_cnt: 115.3, et_cnt: 109.2
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:    8, step    0, Time: 0.0006s, gt_cnt: 115.3, et_cnt: 110.6
# EPOCH: 8, MAE: 19.1, MSE: 24.7
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:    9, step    0, Time: 0.0006s, gt_cnt: 115.3, et_cnt: 111.5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   10, step    0, Time: 0.0005s, gt_cnt: 115.3, et_cnt: 112.2
# EPOCH: 10, MAE: 20.1, MSE: 26.0
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   11, step    0, Time: 0.0005s, gt_cnt: 115.3, et_cnt: 112.6
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   12, step    0, Time: 0.0004s, gt_cnt: 115.3, et_cnt: 112.8
# EPOCH: 12, MAE: 20.9, MSE: 27.0
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   13, step    0, Time: 0.0004s, gt_cnt: 115.3, et_cnt: 113.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   14, step    0, Time: 0.0004s, gt_cnt: 115.3, et_cnt: 113.2
# EPOCH: 14, MAE: 21.6, MSE: 27.8
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   15, step    0, Time: 0.0004s, gt_cnt: 115.3, et_cnt: 113.3
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   16, step    0, Time: 0.0003s, gt_cnt: 115.3, et_cnt: 113.3
# EPOCH: 16, MAE: 22.1, MSE: 28.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   17, step    0, Time: 0.0003s, gt_cnt: 115.3, et_cnt: 113.3
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   18, step    0, Time: 0.0003s, gt_cnt: 115.3, et_cnt: 113.3
# EPOCH: 18, MAE: 22.6, MSE: 29.1
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   19, step    0, Time: 0.0003s, gt_cnt: 115.3, et_cnt: 113.3
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   20, step    0, Time: 0.0002s, gt_cnt: 115.3, et_cnt: 113.3
# EPOCH: 20, MAE: 23.0, MSE: 29.6
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   21, step    0, Time: 0.0003s, gt_cnt: 115.3, et_cnt: 113.2
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   22, step    0, Time: 0.0002s, gt_cnt: 115.3, et_cnt: 113.1
# EPOCH: 22, MAE: 23.3, MSE: 30.0
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   23, step    0, Time: 0.0002s, gt_cnt: 115.3, et_cnt: 113.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   24, step    0, Time: 0.0002s, gt_cnt: 115.3, et_cnt: 112.9
# EPOCH: 24, MAE: 23.6, MSE: 30.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   25, step    0, Time: 0.0002s, gt_cnt: 115.3, et_cnt: 112.8
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   26, step    0, Time: 0.0002s, gt_cnt: 115.3, et_cnt: 112.7
# EPOCH: 26, MAE: 23.9, MSE: 30.7
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   27, step    0, Time: 0.0002s, gt_cnt: 115.3, et_cnt: 112.6
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   28, step    0, Time: 0.0002s, gt_cnt: 115.3, et_cnt: 112.4
# EPOCH: 28, MAE: 24.2, MSE: 31.0
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   29, step    0, Time: 0.0002s, gt_cnt: 115.3, et_cnt: 112.3
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   30, step    0, Time: 0.0002s, gt_cnt: 115.3, et_cnt: 112.2
# EPOCH: 30, MAE: 24.5, MSE: 31.2
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   31, step    0, Time: 0.0002s, gt_cnt: 115.3, et_cnt: 112.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   32, step    0, Time: 0.0002s, gt_cnt: 115.3, et_cnt: 111.9
# EPOCH: 32, MAE: 24.7, MSE: 31.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   33, step    0, Time: 0.0002s, gt_cnt: 115.3, et_cnt: 111.7
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   34, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 111.6
# EPOCH: 34, MAE: 25.0, MSE: 31.6
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   35, step    0, Time: 0.0002s, gt_cnt: 115.3, et_cnt: 111.5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   36, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 111.3
# EPOCH: 36, MAE: 25.2, MSE: 31.7
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   37, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 111.1
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   38, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 111.0
# EPOCH: 38, MAE: 25.3, MSE: 31.8
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   39, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 110.9
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   40, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 110.8
# EPOCH: 40, MAE: 25.5, MSE: 32.0
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   41, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 110.7
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   42, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 110.6
# EPOCH: 42, MAE: 25.7, MSE: 32.1
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   43, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 110.5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   44, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 110.3
# EPOCH: 44, MAE: 25.8, MSE: 32.1
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   45, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 110.2
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   46, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 110.1
# EPOCH: 46, MAE: 25.9, MSE: 32.2
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   47, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 110.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   48, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 109.9
# EPOCH: 48, MAE: 26.0, MSE: 32.3
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   49, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 109.8
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   50, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 109.7
# EPOCH: 50, MAE: 26.1, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   51, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 109.6
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   52, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 109.5
# EPOCH: 52, MAE: 26.2, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   53, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 109.4
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   54, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 109.3
# EPOCH: 54, MAE: 26.3, MSE: 32.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   55, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 109.2
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   56, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 109.1
# EPOCH: 56, MAE: 26.4, MSE: 32.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   57, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 109.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   58, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 108.9
# EPOCH: 58, MAE: 26.5, MSE: 32.6
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   59, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 108.8
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   60, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 108.7
# EPOCH: 60, MAE: 26.5, MSE: 32.6
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   61, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 108.6
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   62, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 108.5
# EPOCH: 62, MAE: 26.6, MSE: 32.6
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   63, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 108.4
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   64, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 108.3
# EPOCH: 64, MAE: 26.6, MSE: 32.7
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   65, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 108.1
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   66, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 108.0
# EPOCH: 66, MAE: 26.7, MSE: 32.7
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   67, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 108.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   68, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 107.8
# EPOCH: 68, MAE: 26.7, MSE: 32.7
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   69, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 107.8
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   70, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 107.7
# EPOCH: 70, MAE: 26.8, MSE: 32.8
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   71, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 107.6
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   72, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 107.5
# EPOCH: 72, MAE: 26.8, MSE: 32.8
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   73, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 107.4
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   74, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 107.3
# EPOCH: 74, MAE: 26.9, MSE: 32.8
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   75, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 107.2
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   76, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 107.1
# EPOCH: 76, MAE: 26.9, MSE: 32.9
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   77, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 107.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   78, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 106.9
# EPOCH: 78, MAE: 27.0, MSE: 32.9
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   79, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 106.8
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   80, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 106.7
# EPOCH: 80, MAE: 27.0, MSE: 32.9
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   81, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 106.7
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   82, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 106.6
# EPOCH: 82, MAE: 27.0, MSE: 32.9
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   83, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 106.5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   84, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 106.4
# EPOCH: 84, MAE: 27.1, MSE: 32.9
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   85, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 106.3
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   86, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 106.2
# EPOCH: 86, MAE: 27.1, MSE: 32.9
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   87, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 106.1
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   88, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 106.0
# EPOCH: 88, MAE: 27.1, MSE: 33.0
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   89, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 106.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   90, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 105.9
# EPOCH: 90, MAE: 27.2, MSE: 33.0
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   91, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 105.8
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   92, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 105.7
# EPOCH: 92, MAE: 27.2, MSE: 33.0
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   93, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 105.6
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   94, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 105.6
# EPOCH: 94, MAE: 27.3, MSE: 33.1
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   95, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 105.5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   96, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 105.4
# EPOCH: 96, MAE: 27.3, MSE: 33.1
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   97, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 105.3
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   98, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 105.3
# EPOCH: 98, MAE: 27.3, MSE: 33.1
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:   99, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 105.2
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  100, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 105.1
# EPOCH: 100, MAE: 27.4, MSE: 33.1
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  101, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 105.1
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  102, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 105.0
# EPOCH: 102, MAE: 27.4, MSE: 33.2
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  103, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 104.9
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  104, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 104.9
# EPOCH: 104, MAE: 27.4, MSE: 33.2
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  105, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 104.8
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  106, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 104.8
# EPOCH: 106, MAE: 27.5, MSE: 33.2
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  107, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 104.7
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  108, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 104.7
# EPOCH: 108, MAE: 27.5, MSE: 33.2
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  109, step    0, Time: 0.0001s, gt_cnt: 115.3, et_cnt: 104.6
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  110, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 104.5
# EPOCH: 110, MAE: 27.5, MSE: 33.3
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  111, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 104.5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  112, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 104.4
# EPOCH: 112, MAE: 27.6, MSE: 33.3
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  113, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 104.4
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  114, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 104.3
# EPOCH: 114, MAE: 27.6, MSE: 33.3
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  115, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 104.2
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  116, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 104.2
# EPOCH: 116, MAE: 27.6, MSE: 33.3
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  117, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 104.1
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  118, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 104.1
# EPOCH: 118, MAE: 27.7, MSE: 33.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  119, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 104.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  120, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 104.0
# EPOCH: 120, MAE: 27.7, MSE: 33.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  121, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.9
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  122, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.9
# EPOCH: 122, MAE: 27.7, MSE: 33.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  123, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.8
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  124, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.8
# EPOCH: 124, MAE: 27.7, MSE: 33.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  125, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.7
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  126, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.7
# EPOCH: 126, MAE: 27.8, MSE: 33.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  127, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.6
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  128, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.6
# EPOCH: 128, MAE: 27.8, MSE: 33.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  129, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.6
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  130, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.5
# EPOCH: 130, MAE: 27.8, MSE: 33.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  131, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  132, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.4
# EPOCH: 132, MAE: 27.8, MSE: 33.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  133, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.4
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  134, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.3
# EPOCH: 134, MAE: 27.9, MSE: 33.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  135, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.3
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  136, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.3
# EPOCH: 136, MAE: 27.9, MSE: 33.6
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  137, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.2
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  138, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.2
# EPOCH: 138, MAE: 27.9, MSE: 33.6
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  139, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.2
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  140, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.1
# EPOCH: 140, MAE: 28.0, MSE: 33.6
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  141, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.1
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  142, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.0
# EPOCH: 142, MAE: 28.0, MSE: 33.6
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  143, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  144, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 103.0
# EPOCH: 144, MAE: 28.0, MSE: 33.7
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  145, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.9
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  146, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.9
# EPOCH: 146, MAE: 28.0, MSE: 33.7
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  147, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.9
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  148, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.8
# EPOCH: 148, MAE: 28.1, MSE: 33.7
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  149, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.8
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  150, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.8
# EPOCH: 150, MAE: 28.1, MSE: 33.7
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  151, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.7
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  152, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.7
# EPOCH: 152, MAE: 28.1, MSE: 33.7
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  153, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.7
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  154, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.6
# EPOCH: 154, MAE: 28.1, MSE: 33.8
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  155, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.6
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  156, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.6
# EPOCH: 156, MAE: 28.2, MSE: 33.8
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  157, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.6
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  158, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.6
# EPOCH: 158, MAE: 28.2, MSE: 33.8
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  159, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  160, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.5
# EPOCH: 160, MAE: 28.2, MSE: 33.8
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  161, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  162, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.4
# EPOCH: 162, MAE: 28.2, MSE: 33.9
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  163, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.4
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  164, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.4
# EPOCH: 164, MAE: 28.3, MSE: 33.9
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  165, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.4
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  166, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.4
# EPOCH: 166, MAE: 28.3, MSE: 33.9
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  167, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.3
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  168, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.3
# EPOCH: 168, MAE: 28.3, MSE: 33.9
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  169, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.3
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  170, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.3
# EPOCH: 170, MAE: 28.3, MSE: 33.9
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  171, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.3
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  172, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.2
# EPOCH: 172, MAE: 28.4, MSE: 34.0
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  173, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.2
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  174, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.2
# EPOCH: 174, MAE: 28.4, MSE: 34.0
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  175, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.2
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  176, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.1
# EPOCH: 176, MAE: 28.4, MSE: 34.0
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  177, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.1
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  178, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.1
# EPOCH: 178, MAE: 28.4, MSE: 34.0
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  179, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.1
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  180, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.1
# EPOCH: 180, MAE: 28.5, MSE: 34.0
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  181, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  182, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.0
# EPOCH: 182, MAE: 28.5, MSE: 34.1
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  183, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  184, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.0
# EPOCH: 184, MAE: 28.5, MSE: 34.1
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  185, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  186, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.0
# EPOCH: 186, MAE: 28.5, MSE: 34.1
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  187, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 102.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  188, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 101.9
# EPOCH: 188, MAE: 28.6, MSE: 34.1
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  189, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 101.9
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  190, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 101.9
# EPOCH: 190, MAE: 28.6, MSE: 34.1
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  191, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 101.9
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  192, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 101.8
# EPOCH: 192, MAE: 28.6, MSE: 34.2
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  193, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 101.8
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  194, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 101.8
# EPOCH: 194, MAE: 28.6, MSE: 34.2
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  195, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 101.8
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  196, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 101.8
# EPOCH: 196, MAE: 28.6, MSE: 34.2
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  197, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 101.8
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  198, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 101.7
# EPOCH: 198, MAE: 28.6, MSE: 34.2
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  199, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 101.7
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  200, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 101.7
# EPOCH: 200, MAE: 28.6, MSE: 34.2
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# ...
# epoch:  929, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  930, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 930, MAE: 26.9, MSE: 32.6
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  931, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  932, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 932, MAE: 26.9, MSE: 32.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  933, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  934, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 934, MAE: 26.9, MSE: 32.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  935, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  936, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 936, MAE: 26.9, MSE: 32.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  937, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  938, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 938, MAE: 26.9, MSE: 32.6
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  939, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  940, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 940, MAE: 26.9, MSE: 32.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  941, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  942, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 942, MAE: 26.9, MSE: 32.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  943, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  944, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 944, MAE: 26.9, MSE: 32.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  945, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  946, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 946, MAE: 26.9, MSE: 32.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  947, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  948, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 948, MAE: 26.9, MSE: 32.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  949, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  950, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 950, MAE: 26.9, MSE: 32.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  951, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  952, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 952, MAE: 26.9, MSE: 32.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  953, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  954, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 954, MAE: 26.8, MSE: 32.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  955, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  956, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 956, MAE: 26.9, MSE: 32.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  957, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  958, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 958, MAE: 26.8, MSE: 32.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  959, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  960, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 960, MAE: 26.8, MSE: 32.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  961, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  962, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 962, MAE: 26.8, MSE: 32.5
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  963, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  964, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 964, MAE: 26.8, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  965, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  966, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.1
# EPOCH: 966, MAE: 26.8, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  967, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  968, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 968, MAE: 26.8, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  969, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  970, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 970, MAE: 26.8, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  971, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  972, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 972, MAE: 26.8, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  973, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  974, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 974, MAE: 26.8, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  975, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  976, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 976, MAE: 26.8, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  977, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  978, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 978, MAE: 26.8, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  979, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.1
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  980, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 980, MAE: 26.8, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  981, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  982, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 982, MAE: 26.8, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  983, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  984, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 984, MAE: 26.8, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  985, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  986, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 986, MAE: 26.7, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  987, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  988, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 988, MAE: 26.7, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  989, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.1
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  990, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# EPOCH: 990, MAE: 26.7, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  991, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  992, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.1
# EPOCH: 992, MAE: 26.7, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  993, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.1
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  994, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.1
# EPOCH: 994, MAE: 26.7, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  995, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  996, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.1
# EPOCH: 996, MAE: 26.7, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  997, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.1
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  998, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.1
# EPOCH: 998, MAE: 26.7, MSE: 32.4
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch:  999, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.0
# <bound method ImageDataLoader.get_num_samples of <__main__.ImageDataLoader object at 0x7f878b0fc2b0>>
# epoch: 1000, step    0, Time: 0.0000s, gt_cnt: 115.3, et_cnt: 99.1
# EPOCH: 1000, MAE: 26.7, MSE: 32.3
# BEST MAE: 13.2, BEST MSE: 16.2, BEST MODEL: mcnn_pretrain_A_to_B_ucfc_2.h5

# %% [markdown]
# testing on dataset shanghaitech part_B or ucfc_cc_50

# %%
torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark = False
vis = False
save_output = True

#data_path =  '/content/gdrive/My Drive/project_folder/crowdcount-mcnn/data/original/shanghaitech/part_B_final/test_data/images/'
#gt_path = '/content/gdrive/My Drive/project_folder/crowdcount-mcnn/data/original/shanghaitech/part_B_final/test_data/ground_truth_csv/'
#model_path = '/content/gdrive/My Drive/project_folder/crowdcount-mcnn/saved_models/mcnn_shtechA_1942.h5'
#model_path = '/content/gdrive/My Drive/project_folder/crowdcount-mcnn/saved_pretrained_last_two_layer_models_A_B/mcnn_pretrain_A_to_B_shtechB_1000.h5'

output_dir = '/content/gdrive/My Drive/project_folder/output/pretrained_last_2_layer_ucfc/'

data_path =  '/content/gdrive/My Drive/project_folder/crowdcount-mcnn/data/original/UCFC/test_data/images/'
gt_path = '/content/gdrive/My Drive/project_folder/crowdcount-mcnn/data/original/UCFC/test_data/ground_truth_csv/'
#model_path = '/content/gdrive/My Drive/project_folder/crowdcount-mcnn/saved_pretrained_models_last_layer/mcnn_pretrain_A_to_B_shtechB_730.h5'
#model_path = '/content/gdrive/My Drive/project_folder/crowdcount-mcnn/saved_pretrained_models_last_layer/mcnn_pretrain_A_to_B_shtechB_290.h5'
model_path = '/content/gdrive/My Drive/project_folder/crowdcount-mcnn/saved_pretrained_last_two_layer_models_A_ucfc/mcnn_pretrain_A_to_B_ucfc_2.h5'

#output_dir = '/content/gdrive/My Drive/project_folder/output/pretrained_A_last_layer_test_data_ucfc/'

model_name = os.path.basename(model_path).split('.')[0]
file_results = os.path.join(output_dir,'results_' + model_name + '_.txt')
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
output_dir = os.path.join(output_dir, 'density_maps_' + model_name)
if not os.path.exists(output_dir):
    os.mkdir(output_dir)


net = CrowdCounter()
      
trained_model = os.path.join(model_path)
load_net(trained_model, net)



net.cuda()
net.eval()
mae = 0.0
mse = 0.0

#load test data
data_loader = ImageDataLoader(data_path, gt_path, shuffle=False, gt_downsample=True, pre_load=True)
print(net)
for blob in data_loader:                        
    im_data = blob['data']
    gt_data = blob['gt_density']
    density_map = net(im_data, gt_data)
    
    density_map = density_map.data.cpu().numpy()
    gt_count = np.sum(gt_data)
    et_count = np.sum(density_map)
    mae += abs(gt_count-et_count)
    mse += ((gt_count-et_count)*(gt_count-et_count))
    if vis:
        display_results(im_data, gt_data, density_map)
    if save_output:
        save_density_map(density_map, output_dir, 'output_' + blob['fname'].split('.')[0] + '.png')
        
mae = mae/data_loader.get_num_samples()
mse = np.sqrt(mse/data_loader.get_num_samples())
print('\nMAE: %0.2f, MSE: %0.2f' % (mae,mse))

f = open(file_results, 'w') 
f.write('MAE: %0.2f, MSE: %0.2f' % (mae,mse))
f.close()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:132: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# CrowdCounter(
#   (DME): MCNN(
#     (branch1): Sequential(
#       (0): Conv2d(
#         (conv): Conv2d(1, 16, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#         (relu): ReLU(inplace=True)
#       )
#       (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): Conv2d(
#         (conv): Conv2d(16, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#         (relu): ReLU(inplace=True)
#       )
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): Conv2d(
#         (conv): Conv2d(32, 16, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#         (relu): ReLU(inplace=True)
#       )
#       (5): Conv2d(
#         (conv): Conv2d(16, 8, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (branch2): Sequential(
#       (0): Conv2d(
#         (conv): Conv2d(1, 20, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#         (relu): ReLU(inplace=True)
#       )
#       (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): Conv2d(
#         (conv): Conv2d(20, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (relu): ReLU(inplace=True)
#       )
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): Conv2d(
#         (conv): Conv2d(40, 20, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (relu): ReLU(inplace=True)
#       )
#       (5): Conv2d(
#         (conv): Conv2d(20, 10, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): Conv2d(
#         (conv): Conv2d(1, 24, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (relu): ReLU(inplace=True)
#       )
#       (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): Conv2d(
#         (conv): Conv2d(24, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): Conv2d(
#         (conv): Conv2d(48, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (5): Conv2d(
#         (conv): Conv2d(24, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (fuse): Sequential(
#       (0): Conv2d(
#         (conv): Conv2d(30, 1, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (loss_fn): MSELoss()
# )
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:255: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# MAE: 767.91, MSE: 970.23
